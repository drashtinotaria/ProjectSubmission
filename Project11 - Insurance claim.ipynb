# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/Insurance claim.csv")

df1 = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/Insurance claim.csv")

df
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# ...       ...     ...        ...       ...           ...      ...       ...
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
# ...

# %%
df.shape
# Out:
# (9134, 26)

# %%
df.dtypes
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# ...

# %%
df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %% [markdown]
# Observations:
#     1. mean < than median(50%) = > None => Left Skewed
#     2. mean > than median(50%) = > Claim Amount,Total Claim => Right Skewed
#     3. mean = than median(50%) = > months Since Last Claim/Inception => Normal Distribution
#     4. Data Large difference between 75 % and max ===> Claim Amount,Monthly Premium, Total Claim Amount ===> Outliers Present

# %% [markdown]
# # Checking NaN VAlues

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %% [markdown]
# No Nan valyes present

# %% [markdown]
# # Checking for ?

# %%
(df == '?').sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %% [markdown]
# # Label Encoder

# %%
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor        02-03-2011         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
# Converting Non Numeric Columns to Numeric

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Country'] = le.fit_transform(df['Country'].astype(str))
df['State Code'] = le.fit_transform(df['State Code'].astype(str))
df['State'] = le.fit_transform(df['State'].astype(str))
df['Education'] = le.fit_transform(df['Education'].astype(str))
df['EmploymentStatus'] = le.fit_transform(df['EmploymentStatus'].astype(str))
df['Gender'] = le.fit_transform(df['Gender'].astype(str))
df['Marital Status'] = le.fit_transform(df['Marital Status'].astype(str))
df['Response'] = le.fit_transform(df['Response'].astype(str))
df['Coverage'] = le.fit_transform(df['Coverage'].astype(str))
df['Location Code'] = le.fit_transform(df['Location Code'].astype(str))
df['Policy Type'] = le.fit_transform(df['Policy Type'].astype(str))
df['Policy'] = le.fit_transform(df['Policy'].astype(str))
df['Claim Reason'] = le.fit_transform(df['Claim Reason'].astype(str))
df['Vehicle Class'] = le.fit_transform(df['Vehicle Class'].astype(str))
df['Vehicle Size'] = le.fit_transform(df['Vehicle Size'].astype(str))
df['Sales Channel'] = le.fit_transform(df['Sales Channel'].astype(str))

# %%
df.head()
# Out:
#   Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0  BU79786        0           1      1    276.351928         0         0
# 1  QZ44356        0           3      3    697.953590         0         1
# 2  AI49188        0           4      4   1288.743165         0         2
# 3  WW63253        0           2      2    764.586183         0         0
# 4  HB64268        0           1      1    281.369258         0         0
#
#    Education Effective To Date  EmploymentStatus  ...  \
# 0          0           2/24/11                 1  ...
# 1          0           1/31/11                 4  ...
# 2          0           2/19/11                 1  ...
# 3          0           1/20/11                 4  ...
# 4          0        02-03-2011                 1  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# ...

# %%
df.dtypes
# Out:
# Customer                          object
# Country                            int32
# State Code                         int32
# State                              int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# Education                          int32
# Effective To Date                 object
# EmploymentStatus                   int32
# Gender                             int32
# Income                             int64
# Location Code                      int32
# Marital Status                     int32
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int32
# Policy                             int32
# Claim Reason                       int32
# Sales Channel                      int32
# ...

# %% [markdown]
# # Univarient Analysis

# %%
# Hgihest claim is made by Employed

df["EmploymentStatus"].plot.hist()

# %%
df1.EmploymentStatus.value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: EmploymentStatus, dtype: int64

# %%
# More claims are made by Females than males

df["Gender"].plot.hist()

# %%
df1.Gender.value_counts()
# Out:
# F    4658
# M    4476
# Name: Gender, dtype: int64

# %%
# Highest claims are made in Suburban (Pivot Table used in CSV)

df["Location Code"].plot.hist()

# %%
# Highest claims are made by Married people (Pivot Table used in CSV)

df["Marital Status"].plot.hist()

# %%
# Highest Claims are made for Personal Auto (Pivot Table used in CSV)

df["Policy Type"].plot.hist()

# %%
# Highest Claim is made for Personal L3 and lowest for Special L1

df["Policy"].plot.hist()

# %%
df1.Policy.value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: Policy, dtype: int64

# %%
# Highest is for Collision (Through Pivot Table used in CSV)

df["Claim Reason"].plot.hist()

# %%
# Highest claim is made for Medsize vehicals (Pivot Table in CSV)

df["Vehicle Size"].plot.hist()

# %% [markdown]
# # Drop Columns

# %%
# We are dropping irrelevent columns => Customer, Country
# Dropping State Code as State is present
# Effective To Date as Months since Inception is present
# We are focusing on analysing Claim Amount based on the Policy type and not related to who is claiming hence deleting those rows

df = df.drop(["Customer" , "Effective To Date"] , axis = 1)

# %%
df
# Out:
#       Country  State Code  State  Claim Amount  Response  Coverage  Education  \
# 0           0           1      1    276.351928         0         0          0
# 1           0           3      3    697.953590         0         1          0
# 2           0           4      4   1288.743165         0         2          0
# 3           0           2      2    764.586183         0         0          0
# 4           0           1      1    281.369258         0         0          0
# ...       ...         ...    ...           ...       ...       ...        ...
# 9129        0           2      2   2340.598798         0         0          0
# 9130        0           2      2    309.651122         1         1          1
# 9131        0           2      2    816.389043         0         1          0
# 9132        0           2      2    752.444244         0         1          1
# 9133        0           2      2    261.183687         0         1          1
#
# ...

# %% [markdown]
# # Bivarient Analysis

# %%
# Amount is highest calimed for Special Auto = 2

sns.barplot(y=df['Claim Amount'], x=df['Policy Type'],data=df)
plt.show()

# %%
# Amount is highest calimed for Corporate L1=0 and Special L3 = 8

sns.barplot(y=df['Claim Amount'], x=df['Policy'],data=df)
plt.show()

# %%
df1.Policy.value_counts() , df.Policy.value_counts()
# Out:
# (Personal L3     3426
#  Personal L2     2122
#  Personal L1     1240
#  Corporate L3    1014
#  Corporate L2     595
#  Corporate L1     359
#  Special L2       164
#  Special L3       148
#  Special L1        66
#  Name: Policy, dtype: int64,
#  5    3426
#  4    2122
#  3    1240
#  2    1014
#  1     595
#  0     359
#  7     164
#  8     148
#  6      66
#  Name: Policy, dtype: int64)

# %%
# Amount is highest for Collision = 0 and lowest for Hail=2 (Pivot table in CSV)

sns.barplot(y=df['Claim Amount'], x=df['Claim Reason'],data=df)
plt.show()

# %% [markdown]
# # Correlation

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                Country  State Code     State  Claim Amount  \
# Country                            NaN         NaN       NaN           NaN
# State Code                         NaN    1.000000  1.000000     -0.006629
# State                              NaN    1.000000  1.000000     -0.006629
# Claim Amount                       NaN   -0.006629 -0.006629      1.000000
# Response                           NaN   -0.001732 -0.001732     -0.008930
# Coverage                           NaN    0.007558  0.007558      0.168040
# Education                          NaN    0.004256  0.004256      0.026038
# EmploymentStatus                   NaN   -0.004054 -0.004054     -0.034846
# Gender                             NaN    0.000545  0.000545     -0.013610
# Income                             NaN    0.002682  0.002682      0.024366
# Location Code                      NaN    0.001382  0.001382      0.004854
# ...

# %%
plt.figure(figsize = (16,16))
sns.heatmap(df.corr() ,  cmap = "Greens" , annot = True)

# %% [markdown]
# Observations:
#     1. Positive Correlation
#     Calim Amount - Monthly Premium Auto
#     2. Negative Correlation
#     Claim Amount - Claim Reason

# %% [markdown]
# # Checking and removing Outliers

# %%
df.dtypes
# Out:
# Country                            int32
# State Code                         int32
# State                              int32
# Claim Amount                     float64
# Response                           int32
# Coverage                           int32
# Education                          int32
# EmploymentStatus                   int32
# Gender                             int32
# Income                             int64
# Location Code                      int32
# Marital Status                     int32
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int32
# Policy                             int32
# Claim Reason                       int32
# Sales Channel                      int32
# Total Claim Amount               float64
# Vehicle Class                      int32
# ...

# %%
collist = df.columns.values

ncol = 10
nrows = 14

collist
# Out:
# array(['Country', 'State Code', 'State', 'Claim Amount', 'Response',
#        'Coverage', 'Education', 'EmploymentStatus', 'Gender', 'Income',
#        'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Claim Reason', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'], dtype=object)

# %%
plt.figure(figsize = (1.5*ncol,10*ncol))
for i in range(0 , len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(df[collist[i]] , color = 'yellow' , orient = 'v')
    plt.tight_layout()

# %% [markdown]
# Outliers are present

# %%
# Removing outliers using Zscore

from scipy.stats import zscore


z = np.abs(zscore(df))
df_new = df[(z<3).all(axis = 1)]

df_new
# Out:
# Empty DataFrame
# Columns: [Country, State Code, State, Claim Amount, Response, Coverage, Education, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Claim Reason, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.shape
# Out:
# (9134, 24)

# %%
df_new.shape
# Out:
# (0, 24)

# %% [markdown]
# 664 rows are removed to remove the outliers

# %% [markdown]
# # Splitting in to Attributes and Target variables

# %%
# Please note we have even dropped Total Claim Amount column

x = df.drop(["Total Claim Amount" ] , axis = 1)

x
# Out:
#       Country  State Code  State  Claim Amount  Response  Coverage  Education  \
# 0           0           1      1    276.351928         0         0          0
# 1           0           3      3    697.953590         0         1          0
# 2           0           4      4   1288.743165         0         2          0
# 3           0           2      2    764.586183         0         0          0
# 4           0           1      1    281.369258         0         0          0
# ...       ...         ...    ...           ...       ...       ...        ...
# 9129        0           2      2   2340.598798         0         0          0
# 9130        0           2      2    309.651122         1         1          1
# 9131        0           2      2    816.389043         0         1          0
# 9132        0           2      2    752.444244         0         1          1
# 9133        0           2      2    261.183687         0         1          1
#
# ...

# %%
y = df["Total Claim Amount"]

y
# Out:
# 0        384.811147
# 1       1131.464935
# 2        566.472247
# 3        529.881344
# 4        138.130879
#            ...
# 9129     198.234764
# 9130     379.200000
# 9131     790.784983
# 9132     691.200000
# 9133     369.600000
# Name: Total Claim Amount, Length: 9134, dtype: float64

# %%
y = y.values.reshape(-1,1)

y.shape , x.shape
# Out:
# ((9134, 1), (9134, 23))

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x2 = sc.fit_transform(x)
x2 = pd.DataFrame(x2,columns = x.columns)
x2
# Out:
#       Country  State Code     State  Claim Amount  Response  Coverage  \
# 0         0.0   -0.550690 -0.550690     -0.762878 -0.408822 -0.732899
# 1         0.0    0.973322  0.973322     -0.149245 -0.408822  0.791999
# 2         0.0    1.735328  1.735328      0.710636 -0.408822  2.316897
# 3         0.0    0.211316  0.211316     -0.052263 -0.408822 -0.732899
# 4         0.0   -0.550690 -0.550690     -0.755575 -0.408822 -0.732899
# ...       ...         ...       ...           ...       ...       ...
# 9129      0.0    0.211316  0.211316      2.241590 -0.408822 -0.732899
# 9130      0.0    0.211316  0.211316     -0.714411  2.446054  0.791999
# 9131      0.0    0.211316  0.211316      0.023135 -0.408822  0.791999
# 9132      0.0    0.211316  0.211316     -0.069935 -0.408822  0.791999
# 9133      0.0    0.211316  0.211316     -0.784955 -0.408822  0.791999
#
#       Education  EmploymentStatus    Gender    Income  ...  \
# 0     -1.124597         -0.612669 -0.980269  0.612827  ...
# ...

# %%
x2
# Out:
#       Country  State Code     State  Claim Amount  Response  Coverage  \
# 0         0.0   -0.550690 -0.550690     -0.762878 -0.408822 -0.732899
# 1         0.0    0.973322  0.973322     -0.149245 -0.408822  0.791999
# 2         0.0    1.735328  1.735328      0.710636 -0.408822  2.316897
# 3         0.0    0.211316  0.211316     -0.052263 -0.408822 -0.732899
# 4         0.0   -0.550690 -0.550690     -0.755575 -0.408822 -0.732899
# ...       ...         ...       ...           ...       ...       ...
# 9129      0.0    0.211316  0.211316      2.241590 -0.408822 -0.732899
# 9130      0.0    0.211316  0.211316     -0.714411  2.446054  0.791999
# 9131      0.0    0.211316  0.211316      0.023135 -0.408822  0.791999
# 9132      0.0    0.211316  0.211316     -0.069935 -0.408822  0.791999
# 9133      0.0    0.211316  0.211316     -0.784955 -0.408822  0.791999
#
#       Education  EmploymentStatus    Gender    Income  ...  \
# 0     -1.124597         -0.612669 -0.980269  0.612827  ...
# ...

# %% [markdown]
# ## Data Analysis - Linear Regression

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y,random_state = 43 , test_size = 0.20)

x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((7307, 23), (1827, 23), (7307, 1), (1827, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score,auc, roc_curve
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
lreg = LinearRegression()
knr = KNeighborsRegressor()
ls = Lasso()
en = ElasticNet()
dtr = DecisionTreeRegressor()

# %%
#Best parameter for Linear Regression

parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
gs = GridSearchCV(lreg , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}

# %%
#Best parameter for KNearestNeighbors

parameters = { 'n_neighbors' : (1,10)}
gs = GridSearchCV(knr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'n_neighbors': 10}

# %%
#Best parameter for Decision Tree

parameters = { "criterion": ["mse", "mae"] }
gs = GridSearchCV(dtr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'criterion': 'mae'}

# %%
lreg = LinearRegression(copy_X = 'True' , fit_intercept = 'True' , normalize = 'False')
knr = KNeighborsRegressor(n_neighbors= 10)
dtr = DecisionTreeRegressor(criterion = 'mae')
svr = SVR()

# %%
# Best Parameter for Random Forest

rf = RandomForestRegressor()
parameters = {  "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(rf , parameters , cv =5)
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'n_estimators': 1000}

# %%
# Best Parameter for Gradient Boosting

gbr = GradientBoostingRegressor()
parameters = { "learning_rate" : [0.001 , 0.01 , 0.1 , 1] , "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(gbr , parameters , cv =5)
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
gbr = GradientBoostingRegressor(learning_rate = 0.01 ,n_estimators = 1000 )
rf = RandomForestRegressor(n_estimators = 1000)

# %%
dtr.fit(x_train,y_train)
pre = dtr.predict(x_test)
r2 = r2_score(y_test,pre)
rme = np.sqrt(mean_squared_error(y_test,pre))

print(r2 , "\n" , rme)
# Out:
# 0.6658264645596702
#  164.03937532134282

# %%
models = []
models.append(('KNeighborsRegressor' , knr))
models.append(('LinearRegression' , lreg))
models.append(('Lasso' , ls))
models.append(('ElasticNet' , en))
models.append(('GradientBooster' , gbr))
models.append(('RandomForestRegressor' , rf))
models.append(('SVR' , svr))
models.append(('Decision Tree Regressor' , dtr))

models
# Out:
# [('KNeighborsRegressor',
#   KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                       weights='uniform')),
#  ('LinearRegression',
#   LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                    normalize='False')),
#  ('Lasso',
#   Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#         normalize=False, positive=False, precompute=False, random_state=None,
#         selection='cyclic', tol=0.0001, warm_start=False)),
#  ('ElasticNet',
#   ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#              max_iter=1000, normalize=False, positive=False, precompute=False,
#              random_state=None, selection='cyclic', tol=0.0001, warm_start=False)),
#  ('GradientBooster',
#   GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
# ...

# %%
Model = []
r2score = []
cv = []
rmse = []

for name,model in models:
    print("***************************" , name , "***************************\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    r2s = r2_score(y_test,pred)
    print("r2 score :" , r2s)
    r2score.append(r2s*100)
    print("\n")
    sc = cross_val_score(model , x, y , cv = 10 , scoring = 'r2')
    print("Cross_Val_score : " , sc)
    cv.append(sc*100)
    print("\n")
    rme = np.sqrt(mean_squared_error(y_test,pred))
    print("RMSE : " , rme)
    rmse.append(rme)
    print("\n\n")
# Out:
# *************************** KNeighborsRegressor ***************************
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
#
# r2 score : 0.6717171460958997
#
#
# Cross_Val_score :  [0.28756551 0.30749571 0.28983479 0.31247116 0.36045739 0.40315423
#  0.40014329 0.30881173 0.33888136 0.41454575]
#
#
# RMSE :  162.58713572906893
#
#
#
# *************************** LinearRegression ***************************
#
# LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                  normalize='False')
#
#
# r2 score : 0.6090457123718093
#
#
# Cross_Val_score :  [0.59860152 0.63324209 0.56278848 0.57830366 0.58351009 0.61652448
#  0.62376589 0.61833606 0.60871344 0.62344844]
#
#
# RMSE :  177.42919016397715
#
#
#
# *************************** Lasso ***************************
#
# ...

# %%
result = pd.DataFrame({'Model' : Model , 'R2Score' : r2score , "RMSE" : rmse , "Cross_Val_Score" :cv})

result
# Out:
#                      Model    R2Score        RMSE  \
# 0      KNeighborsRegressor  67.171715  162.587136
# 1         LinearRegression  60.904571  177.429190
# 2                    Lasso  60.884287  177.475212
# 3               ElasticNet  55.061799  190.226021
# 4          GradientBooster  83.509439  115.233775
# 5    RandomForestRegressor  83.174187  116.399230
# 6                      SVR  25.964806  244.163752
# 7  Decision Tree Regressor  65.834025  165.866618
#
#                                      Cross_Val_Score
# 0  [28.756551031109268, 30.7495709978444, 28.9834...
# 1  [59.86015195485523, 63.32420930944005, 56.2788...
# 2  [59.73520375469111, 63.305927378269125, 56.288...
# 3  [55.701420366874, 60.16420643898934, 53.285542...
# 4  [82.24273856144885, 83.97975700811213, 83.9432...
# 5  [83.43874737822904, 84.43092500925196, 84.8289...
# 6  [10.645185484412655, 8.963561410898624, 8.7544...
# 7  [67.41642642492538, 70.24439826870712, 62.9664...

# %%
# Best Model we consider is Random Forest as it has highest R2Score

max_r2 = 0

for rs in range(30,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = rs , test_size = 0.20)
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    r2s = r2_score(y_test,pred)
    if r2s > max_r2:
        max_r2 = r2s
        final_rm = rs
        print("Max R2 Score : " , max_r2 , "Max Random State" , final_rm)
# Out:
# Max R2 Score :  0.8402279529221932 Max Random State 30
# Max R2 Score :  0.8514038783973308 Max Random State 31
# Max R2 Score :  0.8605512849812179 Max Random State 34

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y,random_state = 34 , test_size = 0.20)

rf.fit(x_train,y_train)
pred=rf.predict(x_test)
R2Score= r2_score(y_test,pred)

print("R2Score : " , R2Score)
# Out:
# R2Score :  0.8612833962847083

# %% [markdown]
# # Predicting the values

# %%
# Random Forestmodel as it has comapratively better r2score

df_pred = rf.predict(x_test)

df_predict = pd.DataFrame(df_pred)

df_predict

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib

# Save the model as a object file

joblib.dump(rf , 'p11_Insuranceclaim.obj')

#Load the model from the file

dtc_from_joblib = joblib.load('p11_Insuranceclaim.obj')

# Use the loaded model to make predictions

dtc_from_joblib.predict(x_test)

# %%
# Saving Predict to csv

df_predict.to_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/insuranceclaim_predict.csv")
