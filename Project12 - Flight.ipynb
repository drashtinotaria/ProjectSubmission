# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/flight train.csv")

df1 = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/flight train.csv")

df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
test = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/flight test.csv")

test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL ? BOM ? COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU ? MAA ? BLR    06:20         10:20       4h      1 stop
# ...

# %%
df.dtypes , test.dtypes
# Out:
# (Airline            object
#  Date_of_Journey    object
#  Source             object
#  Destination        object
#  Route              object
#  Dep_Time           object
#  Arrival_Time       object
#  Duration           object
#  Total_Stops        object
#  Additional_Info    object
#  Price               int64
#  dtype: object,
#  Airline            object
#  Date_of_Journey    object
#  Source             object
#  Destination        object
#  Route              object
#  Dep_Time           object
#  Arrival_Time       object
#  Duration           object
#  Total_Stops        object
#  Additional_Info    object
#  dtype: object)

# %%
df = df.drop(["Arrival_Time"] , axis = 1)

test = test.drop(["Arrival_Time"] , axis = 1)

# %%
df.shape , test.shape
# Out:
# ((10683, 10), (2671, 9))

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# Observations:
#     1. mean > Median(50%) => Right Skewed Data
#     2. Difference between 75% and max is very high => Outliers are present

# %% [markdown]
# # Checking NaN values

# %%
sns.heatmap(df.isnull())

# %%
sns.heatmap(test.isnull())

# %% [markdown]
# No Nan values are present

# %% [markdown]
# # Checking ?

# %%
(df == '?').sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
(test == '?').sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# # Using Label Encoder

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

list = ["Airline" , "Date_of_Journey" , "Source" , "Destination" , "Route" , "Dep_Time" , "Duration" , "Total_Stops" , 
       "Additional_Info"]

for i in range(len(list)):
    df[list[i]] = le.fit_transform(df[list[i]].astype(str))
df
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            5               17       0            5     39       126
# 1            1               40       3            0    112       147
# 2            6               38       2            1     22       190
# 3            5                2       3            0    120        73
# 4            5                0       0            5     51        56
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               36       3            0     90        94
# 10679        1               22       3            0     90       105
# 10680        6               22       0            2     39       176
# 10681        2                0       0            5     39       214
# 10682        1               37       2            1     11       206
#
#        Duration  Total_Stops  Additional_Info  Price
# 0           158            5                8   3897
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

list = ["Airline" , "Date_of_Journey" , "Source" , "Destination" , "Route" , "Dep_Time" , "Duration" , "Total_Stops" , 
       "Additional_Info"]

for i in range(len(list)):
    test[list[i]] = le.fit_transform(test[list[i]].astype(str))
test
# Out:
#       Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0           4               39       2            1     76       138
# 1           3               10       3            0     65        31
# 2           4               22       2            1     76       156
# 3           6               22       2            1     76        48
# 4           0               27       0            2     16       198
# ...       ...              ...     ...          ...    ...       ...
# 2666        1               39       3            0     51       170
# 2667        3               28       3            0     43       106
# 2668        4               36       2            1     76       183
# 2669        1               36       2            1     76        11
# 2670        6               15       2            1     76        15
#
#       Duration  Total_Stops  Additional_Info
# 0           10            0                5
# 1          248            0                5
# ...

# %% [markdown]
# # Univariant Analysis

# %%
# Maxium flights are of Jet Airways and then Indigo

df["Airline"].plot.hist()

# %%
df1.Airline.value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
# Maximum flights are starting from Delhi

df["Source"].plot.hist()

# %%
df1.Source.value_counts()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
# Maximum flights are bound to Cochim and least to Kolkata

df["Destination"].plot.hist()

# %%
df1.Destination.value_counts()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
# Maxium flights where info is present have in-flight meal not included

df["Additional_Info"].plot.hist()

# %%
df1.Additional_Info.value_counts()
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 2 Long layover                     1
# Red-eye flight                     1
# 1 Short layover                    1
# Name: Additional_Info, dtype: int64

# %%
# Maximum flights have one stop 

df["Total_Stops"].plot.hist()

# %%
df1.Total_Stops.value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# # Bivarient Analysis

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
# prices are highest for Jet Airways Business

sns.barplot(y=df['Price'], x=df['Airline'],data=df)
plt.show()

# %%
df.Airline.value_counts()
# Out:
# 6     3849
# 5     2053
# 1     1752
# 8     1196
# 10     818
# 2      479
# 0      319
# 4      194
# 9       13
# 7        6
# 3        3
# 11       1
# Name: Airline, dtype: int64

# %%
# prices are highest for Delhi = source

sns.barplot(y=df['Price'], x=df['Source'],data=df)
plt.show()

# %%
# prices are highest for Delhi = Destination

sns.barplot(y=df['Price'], x=df['Destination'],data=df)
plt.show()

# %%
# prices are highest for 4 + Stops

sns.barplot(y=df['Price'], x=df['Total_Stops'],data=df)
plt.show()

# %% [markdown]
# # Multivarient Analysis

# %%
df.plot.area()

# %% [markdown]
# # Correlation

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                   Airline  Date_of_Journey    Source  Destination     Route  \
# Airline          1.000000         0.014941  0.027838    -0.011180 -0.112244
# Date_of_Journey  0.014941         1.000000  0.117977    -0.171614 -0.018695
# Source           0.027838         0.117977  1.000000    -0.592574  0.388369
# Destination     -0.011180        -0.171614 -0.592574     1.000000 -0.182292
# Route           -0.112244        -0.018695  0.388369    -0.182292  1.000000
# Dep_Time         0.023867        -0.016094 -0.097511     0.064603 -0.098342
# Duration         0.082034         0.004460 -0.127554    -0.143778 -0.149470
# Total_Stops     -0.037116        -0.031065 -0.227074     0.340446  0.092310
# Additional_Info -0.206187         0.010980 -0.022107     0.026806 -0.021319
# Price            0.015266        -0.014877  0.015998    -0.071112 -0.020791
#
#                  Dep_Time  Duration  Total_Stops  Additional_Info     Price
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df.corr() ,  cmap = "Greens" , annot = True)

# %%
Observations:
    1. Price is positively related to 
    2. Price is negatively related to

# %% [markdown]
# # Outliers

# %%
collist = df.columns.values

ncol = 14
nrows = 10

collist
# Out:
# array(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price'],
#       dtype=object)

# %%
plt.figure(figsize = (ncol,5*ncol))
for i in range(0 , len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(df[collist[i]] , color = 'red' , orient = 'v')
    plt.tight_layout()

# %% [markdown]
# Outliers are persent in the data

# %%
# Removing outliers using Zscore

from scipy.stats import zscore


z = np.abs(zscore(df))
df_new = df[(z<3).all(axis = 1)]

df_new
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            5               17       0            5     39       126
# 1            1               40       3            0    112       147
# 2            6               38       2            1     22       190
# 3            5                2       3            0    120        73
# 4            5                0       0            5     51        56
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               36       3            0     90        94
# 10679        1               22       3            0     90       105
# 10680        6               22       0            2     39       176
# 10681        2                0       0            5     39       214
# 10682        1               37       2            1     11       206
#
#        Duration  Total_Stops  Additional_Info  Price
# 0           158            5                8   3897
# ...

# %%
# 105 rows removed to remove outlier

df.shape , df_new.shape
# Out:
# ((10683, 10), (10578, 10))

# %%
collist = test.columns.values

ncol = 14
nrows = 10

collist
# Out:
# array(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Duration', 'Total_Stops', 'Additional_Info'],
#       dtype=object)

# %%
plt.figure(figsize = (ncol,5*ncol))
for i in range(0 , len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(test[collist[i]] , color = 'yellow' , orient = 'v')
    plt.tight_layout()

# %%
# Removing outliers using Zscore

z1 = np.abs(zscore(test))
test_new = test[(z1<3).all(axis = 1)]

test_new
# Out:
#       Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0           4               39       2            1     76       138
# 1           3               10       3            0     65        31
# 2           4               22       2            1     76       156
# 3           6               22       2            1     76        48
# 4           0               27       0            2     16       198
# ...       ...              ...     ...          ...    ...       ...
# 2666        1               39       3            0     51       170
# 2667        3               28       3            0     43       106
# 2668        4               36       2            1     76       183
# 2669        1               36       2            1     76        11
# 2670        6               15       2            1     76        15
#
#       Duration  Total_Stops  Additional_Info
# 0           10            0                5
# 1          248            0                5
# ...

# %%
# 3 rows removed to remove outliers

test_new.shape , test.shape
# Out:
# ((2668, 9), (2671, 9))

# %% [markdown]
# # Splitting in to Attributes and Target variables

# %%
x = df_new.drop(["Price"] , axis = 1)

x
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            5               17       0            5     39       126
# 1            1               40       3            0    112       147
# 2            6               38       2            1     22       190
# 3            5                2       3            0    120        73
# 4            5                0       0            5     51        56
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               36       3            0     90        94
# 10679        1               22       3            0     90       105
# 10680        6               22       0            2     39       176
# 10681        2                0       0            5     39       214
# 10682        1               37       2            1     11       206
#
#        Duration  Total_Stops  Additional_Info
# 0           158            5                8
# ...

# %%
y = df_new["Price"]

y
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10578, dtype: int64

# %%
y = y.values.reshape(-1,1)

y.shape, x.shape , test.shape
# Out:
# ((10578, 1), (10578, 9), (2671, 9))

# %% [markdown]
# # Scaling x

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x1 = x

x2 = sc.fit_transform(x1)
x2 = pd.DataFrame(x2,columns = x1.columns)
x2

# Using x as skewness isnt gettting removed
# Out:
#         Airline  Date_of_Journey    Source  Destination     Route  Dep_Time  \
# 0     -0.046932        -0.401425 -1.681019     2.480267 -0.245448  0.038433
# 1     -1.547908         1.439250  0.884283    -0.972964  1.671177  0.381949
# 2      0.328312         1.279191  0.029182    -0.282317 -0.691785  1.085339
# 3     -0.046932        -1.601866  0.884283    -0.972964  1.881219 -0.828536
# 4     -0.046932        -1.761924 -1.681019     2.480267  0.069614 -1.106620
# ...         ...              ...       ...          ...       ...       ...
# 10573 -1.923152         1.119132  0.884283    -0.972964  1.093564 -0.485020
# 10574 -1.547908        -0.001279  0.884283    -0.972964  1.093564 -0.305083
# 10575  0.328312        -0.001279 -1.681019     0.408329 -0.245448  0.856328
# 10576 -1.172664        -1.761924 -1.681019     2.480267 -0.245448  1.477928
# 10577 -1.547908         1.199162  0.029182    -0.282317 -0.980591  1.347065
#
#        Duration  Total_Stops  Additional_Info
# ...

# %%
x_test = test

x3 = sc.fit_transform(x_test)
x3 = pd.DataFrame(x3,columns = x_test.columns)
x3
# Out:
#        Airline  Date_of_Journey    Source  Destination     Route  Dep_Time  \
# 0     0.011908         1.223690  0.032567    -0.294882  0.797952  0.764507
# 1    -0.423779        -1.090078  0.877086    -0.976222  0.392406 -1.194815
# 2     0.011908        -0.132657  0.032567    -0.294882  0.797952  1.094113
# 3     0.883281        -0.132657  0.032567    -0.294882  0.797952 -0.883521
# 4    -1.730840         0.266269 -1.656471     0.386458 -1.414118  1.863193
# ...        ...              ...       ...          ...       ...       ...
# 2666 -1.295153         1.223690  0.877086    -0.976222 -0.123744  1.350473
# 2667 -0.423779         0.346054  0.877086    -0.976222 -0.418687  0.178542
# 2668  0.011908         0.984335  0.032567    -0.294882  0.797952  1.588521
# 2669 -1.295153         0.984335  0.032567    -0.294882  0.797952 -1.561044
# 2670  0.883281        -0.691152  0.032567    -0.294882  0.797952 -1.487798
#
#       Duration  Total_Stops  Additional_Info
# ...

# %% [markdown]
# # Data Analysis - Linear Regression

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
lreg = LinearRegression()
knr = KNeighborsRegressor()
ls = Lasso()
en = ElasticNet()
dtr = DecisionTreeRegressor()

# %%
# Using unscaled data as models perform better with it
# Using only df i.e. train data for train_test_split as test data doesnot have target attribute


x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 43 , test_size = 0.20)

x_train.shape ,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((8462, 9), (2116, 9), (8462, 1), (2116, 1))

# %%
#Best parameter for Linear Regression

parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
gs = GridSearchCV(lreg , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
#Best parameter for KNearestNeighbors

parameters = { 'n_neighbors' : (1,10)}
gs = GridSearchCV(knr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'n_neighbors': 10}

# %%
#Best parameter for Decision Tree

parameters = { "criterion": ["mse", "mae"] }
gs = GridSearchCV(dtr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'criterion': 'mse'}

# %%
lreg = LinearRegression(copy_X = 'True' , fit_intercept = 'True' , normalize = 'True')
knr = KNeighborsRegressor(n_neighbors= 10)
dtr = DecisionTreeRegressor(criterion = 'mse')
svr = SVR()

# %%
lreg.fit(x_train,y_train)
pred=lreg.predict(x_test)
R2Score= r2_score(y_test,pred)

print("R2Score : " , R2Score)
# Out:
# R2Score :  0.42423093786081867

# %%
# Best Parameter for Random Forest

rf = RandomForestRegressor()
parameters = {  "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(rf , parameters , cv =5)
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'n_estimators': 1000}

# %%
# Best Parameter for Gradient Boosting

gbr = GradientBoostingRegressor()
parameters = { "learning_rate" : [0.001 , 0.01 , 0.1 , 1] , "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(gbr , parameters , cv =5)
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
gbr = GradientBoostingRegressor(learning_rate = 0.1 ,n_estimators = 1000 )
rf = RandomForestRegressor(n_estimators = 1000)

# %%
models = []
models.append(('KNeighborsRegressor' , knr))
models.append(('LinearRegression' , lreg))
models.append(('Lasso' , ls))
models.append(('ElasticNet' , en))
models.append(('GradientBooster' , gbr))
models.append(('RandomForestRegressor' , rf))
models.append(('SVR' , svr))

models
# Out:
# [('KNeighborsRegressor',
#   KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                       weights='uniform')),
#  ('LinearRegression',
#   LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                    normalize='True')),
#  ('Lasso',
#   Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#         normalize=False, positive=False, precompute=False, random_state=None,
#         selection='cyclic', tol=0.0001, warm_start=False)),
#  ('ElasticNet',
#   ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#              max_iter=1000, normalize=False, positive=False, precompute=False,
#              random_state=None, selection='cyclic', tol=0.0001, warm_start=False)),
#  ('GradientBooster',
#   GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
# ...

# %%
Model = []
r2score = []
cv = []
rmse = []

for name,model in models:
    print("***************************" , name , "***************************\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    r2s = r2_score(y_test,pred)
    print("r2 score :" , r2s)
    r2score.append(r2s*100)
    print("\n")
    sc = cross_val_score(model , x, y , cv = 10 , scoring = 'r2')
    print("Cross_Val_score : " , sc)
    cv.append(sc*100)
    print("\n")
    rme = np.sqrt(mean_squared_error(y_test,pred))
    print("RMSE : " , rme)
    rmse.append(rme)
    print("\n\n")
# Out:
# *************************** KNeighborsRegressor ***************************
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
#
# r2 score : 0.6108528072088428
#
#
# Cross_Val_score :  [0.61143628 0.63076848 0.61321312 0.60932443 0.59761155 0.61226839
#  0.59269707 0.55799957 0.60438841 0.58726279]
#
#
# RMSE :  2523.1966783463686
#
#
#
# *************************** LinearRegression ***************************
#
# LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                  normalize='True')
#
#
# r2 score : 0.42423093786081867
#
#
# Cross_Val_score :  [0.40820025 0.41986779 0.44511357 0.45069704 0.42696757 0.42308781
#  0.4334956  0.38175473 0.41266897 0.41369633]
#
#
# RMSE :  3069.151423768648
#
#
#
# *************************** Lasso ***************************
#
# ...

# %%
result = pd.DataFrame({'Model' : Model , 'R2Score' : r2score , "RMSE" : rmse , "Cross_Val_Score" :cv})

result
# Out:
#                    Model    R2Score         RMSE  \
# 0    KNeighborsRegressor  61.085281  2523.196678
# 1       LinearRegression  42.423094  3069.151424
# 2                  Lasso  42.424279  3069.119833
# 3             ElasticNet  41.525012  3092.995044
# 4        GradientBooster  90.526975  1244.911546
# 5  RandomForestRegressor  90.070482  1274.554010
# 6                    SVR   0.704665  4030.496763
#
#                                      Cross_Val_Score
# 0  [61.143627849105705, 63.07684793230985, 61.321...
# 1  [40.82002452307149, 41.986779285836384, 44.511...
# 2  [40.82234779278936, 41.98638804281391, 44.5096...
# 3  [40.531447198849854, 40.8655210781744, 43.1332...
# 4  [89.66056835187543, 90.92518753383273, 89.7030...
# 5  [89.64772792434346, 90.511350530782, 90.721169...
# 6  [0.9027477667270412, -1.0305023395630553, -1.7...

# %%
# Best Model we consider is Gradient Booster as it has highest R2Score

max_r2 = 0

for rs in range(30,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = rs , test_size = 0.20)
    gbr.fit(x_train,y_train)
    pred=gbr.predict(x_test)
    r2s = r2_score(y_test,pred)
    if r2s > max_r2:
        max_r2 = r2s
        final_rm = rs
        print("Max R2 Score : " , max_r2 , "Max Random State" , final_rm)
# Out:
# Max R2 Score :  0.8922982470681247 Max Random State 30
# Max R2 Score :  0.9059991092775939 Max Random State 31
# Max R2 Score :  0.9104843584515545 Max Random State 34
# Max R2 Score :  0.9106025812100546 Max Random State 74
# Max R2 Score :  0.9151943071966633 Max Random State 76

# %%
# Best Model we consider is Gradient Booster as it has highest R2Score

max_r2 = 0

for rs in range(30,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = rs , test_size = 0.20)
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    r2s = r2_score(y_test,pred)
    if r2s > max_r2:
        max_r2 = r2s
        final_rm = rs
        print("Max R2 Score : " , max_r2 , "Max Random State" , final_rm)
# Out:
# Max R2 Score :  0.8949628096774763 Max Random State 30
# Max R2 Score :  0.9077602166343575 Max Random State 31
# Max R2 Score :  0.9142118545284362 Max Random State 34

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 76 , test_size = 0.20)

gbr.fit(x_train,y_train)
pred=gbr.predict(x_test)
R2Score= r2_score(y_test,pred)

print("R2Score : " , R2Score)
# Out:
# R2Score :  0.9152801592242306

# %% [markdown]
# # Predicting the values

# %%
# Gradient Booster as it has comapratively better r2score

df_pred = gbr.predict(test)

df_predict = pd.DataFrame(df_pred)

df_predict
# Out:
#                  0
# 0      4346.680408
# 1      7527.848550
# 2      7235.102238
# 3     10150.989815
# 4      4680.700923
# ...            ...
# 2666   6436.418213
# 2667   5615.942223
# 2668   5489.536983
# 2669   6508.051157
# 2670  10556.028450
#
# [2671 rows x 1 columns]

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib

# Save the model as a object file

joblib.dump(gbr , 'p12_flight.obj')

#Load the model from the file

dtc_from_joblib = joblib.load('p12_flight.obj')

# Use the loaded model to make predictions

dtc_from_joblib.predict(test)
# Out:
# array([ 4346.68040754,  7527.84855033,  7235.10223773, ...,
#         5489.53698314,  6508.05115724, 10556.02845003])

# %%
# Saving Predict to csv

df_predict.to_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/flight_predict.csv")
