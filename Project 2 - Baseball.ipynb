# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/baseball.csv")

df
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42       139    383         973
# 1     83   696     5467  1349      277       44       156    439        1264
# 2     81   669     5439  1395      303       29       141    533        1157
# 3     76   622     5533  1381      260       27       136    404        1231
# 4     74   689     5605  1515      289       49       151    455        1259
# 5     93   891     5509  1480      308       17       232    570        1151
# 6     87   764     5567  1397      272       19       212    554        1227
# 7     81   713     5485  1370      246       20       217    418        1331
# 8     80   644     5485  1383      278       32       167    436        1310
# 9     78   748     5640  1495      294       33       161    478        1148
# 10    88   751     5511  1419      279       32       172    503        1233
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe()
# Out:
#              Wins        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# Observaions:
#
# 1. Mean is less than Median (50%) ===> ERA ==> Left Skewed Data
# 2. Mean is same as Median (50%) ===> runs, At Bats,Doubles,Triples,Stolen Bases,  ==> Normal Distribution
# 3. Mean is more than Median (50%) ===> Hits ==> Right Skewed Data
# 4. Large difference between 75 % and max ===> Doubles, Wins,Homeruns,Strikeouts, Stolen Bases,CG,Shutouts, Saves and Errors   ===> Outliers Present

# %% [markdown]
# # Checking NAN values

# %%
df.isnull().sum()
# Out:
# Wins                        0
# Runs                        0
# At Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# Homeruns                    0
# Walks                       0
# Strikeouts                  0
# Stolen Bases                0
# Runs Allowed                0
# Earned Runs                 0
# Earned Run Average (ERA)    0
# CG                          0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# No NAN values present

# %% [markdown]
# # Checking ?

# %%
(df=='?').sum()

# No ? present
# Out:
# Wins                        0
# Runs                        0
# At Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# Homeruns                    0
# Walks                       0
# Strikeouts                  0
# Stolen Bases                0
# Runs Allowed                0
# Earned Runs                 0
# Earned Run Average (ERA)    0
# CG                          0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %% [markdown]
# # Label Encoder

# %% [markdown]
# Not Required as values for all columns are integers

# %% [markdown]
# # Univarient Analysis

# %%
df["Runs"].plot.hist()

# %% [markdown]
# Frequency for runs between 650-700 is the highest

# %%
df["Earned Runs"].plot.hist()

# %% [markdown]
# Frequency for 650-700 is maximum

# %% [markdown]
# # Bivarient Analysis

# %%
sns.barplot(x=df['Doubles'], y=df['Runs'],data=df)
plt.show()

# %% [markdown]
# Highest Doubles were when run was more than 800

# %%
sns.barplot(x=df['Triples'], y=df['Runs'],data=df)
plt.show()

# %% [markdown]
# Highest Run was scored when truples were around 16-17

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                               Wins      Runs   At Bats      Hits   Doubles  \
# Wins                      1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                      0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats                  -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                      0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles                   0.427797  0.560084  0.453370  0.566847  1.000000
# Triples                  -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns                  0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                     0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts                0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases             -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed             -0.812952 -0.041623  0.316010  0.224324 -0.218160
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df.corr() ,  cmap = "Greens" , annot = True)

# %% [markdown]
# Observations
#
# Positively correlated -
#
# Wins - Saves ==> Highly positive
# Wins - Runs, Doubles, Walks and Shutouts
#
# Negatively correlated -
#
# Wins - Runs Allowed, Earned Runs and ERA

# %% [markdown]
# # Checking out Outliers and removing

# %%
col_list = df.columns.values

ncols = 10
nrows = 12

# %%
plt.figure(figsize = (ncols, 5*ncols))
for i in range( 0 , len(col_list)):
    plt.subplot(nrows , ncols , i+1)
    sns.boxplot(df[col_list[i]] , color = 'yellow' , orient = 'v')
    plt.tight_layout()

# %% [markdown]
# Observations :
# Outliers are present in Runs, ERA , Shutouts, Saves and Error(Highest outliers)

# %%
from scipy.stats import zscore


z = np.abs(zscore(df))

df_new = df[(z<3).all(axis = 1) ]

df_new
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42       139    383         973
# 1     83   696     5467  1349      277       44       156    439        1264
# 2     81   669     5439  1395      303       29       141    533        1157
# 3     76   622     5533  1381      260       27       136    404        1231
# 4     74   689     5605  1515      289       49       151    455        1259
# 6     87   764     5567  1397      272       19       212    554        1227
# 7     81   713     5485  1370      246       20       217    418        1331
# 8     80   644     5485  1383      278       32       167    436        1310
# 9     78   748     5640  1495      294       33       161    478        1148
# 10    88   751     5511  1419      279       32       172    503        1233
# 11    86   729     5459  1363      278       26       230    486        1392
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# One row has been removed to remove the outlier from the data

# %% [markdown]
# # Splitting in to Attributes and Target variables

# %%
x = df_new.drop(["Wins"] , axis = 1)

x
# Out:
#     Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    724     5575  1497      300       42       139    383         973
# 1    696     5467  1349      277       44       156    439        1264
# 2    669     5439  1395      303       29       141    533        1157
# 3    622     5533  1381      260       27       136    404        1231
# 4    689     5605  1515      289       49       151    455        1259
# 6    764     5567  1397      272       19       212    554        1227
# 7    713     5485  1370      246       20       217    418        1331
# 8    644     5485  1383      278       32       167    436        1310
# 9    748     5640  1495      294       33       161    478        1148
# 10   751     5511  1419      279       32       172    503        1233
# 11   729     5459  1363      278       26       230    486        1392
# 12   661     5417  1331      243       21       176    435        1150
# ...

# %%
x.shape
# Out:
# (29, 16)

# %%
y = df_new["Wins"]

y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %%
y = y.values.reshape(-1,1)

y.shape
# Out:
# (29, 1)

# %% [markdown]
# As seen above all the values are below 0.55. Hence skewness is removed from attribute i.e. x1

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x2 = sc.fit_transform(x1)
x2 = pd.DataFrame(x2,columns = x1.columns)
x2
# Out:
#         Runs   At Bats  Hits   Doubles   Triples  Homeruns     Walks  \
# 0   0.959398  0.830084  -1.0  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831  -1.0  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253  -1.0  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951  -1.0 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  -1.0  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535  -1.0 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345  -1.0 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345  -1.0  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  -1.0  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  -1.0  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380  -1.0  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514  -1.0 -1.802414 -1.068901  0.506228 -0.569402
# 12 -0.566355  0.390081  -1.0 -0.682763 -0.969865  1.262607  0.230197
# ...

# %%
x2.skew()
# Out:
# Runs                       -0.215364
# At Bats                     0.169573
# Hits                        0.000000
# Doubles                    -0.335304
# Triples                     0.090124
# Homeruns                    0.450862
# Walks                       0.151193
# Strikeouts                 -0.233815
# Stolen Bases                0.494966
# Runs Allowed                0.018155
# Earned Runs                 0.018461
# Earned Run Average (ERA)    0.016693
# CG                          0.000000
# Shutouts                    0.526943
# Saves                       0.000000
# Errors                      0.000000
# dtype: float64

# %%
x = x2

# %% [markdown]
# # Data Analysis - Linear Regression Model¶

# %%
from sklearn.model_selection import train_test_split, cross_val_score

x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 46 , test_size = 0.20)

# %%
x_train.shape ,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((23, 16), (6, 16), (23, 1), (6, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score,auc, roc_curve
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
lreg = LinearRegression()
knr = KNeighborsRegressor()
ls = Lasso()
en = ElasticNet()
dtr = DecisionTreeRegressor()

# %%
#Best parameter for Linear Regression

parameters = { 'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
gs = GridSearchCV(lreg , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
#Best parameter for KNearestNeighbors

parameters = { 'n_neighbors' : (1,10)}
gs = GridSearchCV(knr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'n_neighbors': 10}

# %%
#Best parameter for Decision Tree

parameters = { "criterion": ["mse", "mae"] }
gs = GridSearchCV(dtr , parameters )
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# {'criterion': 'mae'}

# %%
lreg = LinearRegression(copy_X = 'True' , fit_intercept = 'True' , normalize = 'False')
knr = KNeighborsRegressor(n_neighbors= 10)
dtr = DecisionTreeRegressor(criterion = 'mae')
svr = SVR()
en = ElasticNet()

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Best Parameter for Gradient Boosting

gbr = GradientBoostingRegressor()
parameters = { "learning_rate" : [0.001 , 0.01 , 0.1 , 1] , "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(gbr , parameters , cv =5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 10}

# %%
#Best parameters for Ada booter

abr = AdaBoostRegressor()
dtr = DecisionTreeRegressor()
parameters = { "learning_rate" : [0.001 , 0.01 , 0.1 , 1] , "n_estimators" : [10 , 100 , 500 , 1000] , 
              "base_estimator" :[lreg, ls , dtr , knr]}
gs = GridSearchCV(abr , parameters , cv = 5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'base_estimator': LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                   normalize='False'),
#  'learning_rate': 0.1,
#  'n_estimators': 100}

# %%
# Beat parameter for Random Forest

rf = RandomForestRegressor()
parameters = {  "n_estimators" : [10 , 100 , 500 , 1000]}
gs = GridSearchCV(rf , parameters , cv =5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'n_estimators': 1000}

# %%
gbr = GradientBoostingRegressor(learning_rate = 0.01 ,n_estimators = 10 )
abr = AdaBoostRegressor(learning_rate =0.1 ,n_estimators = 100, base_estimator = lreg)
rf = RandomForestRegressor(n_estimators = 1000)

# %%
models = []
models.append(('KNeighborsRegressor' , knr))
models.append(('LinearRegression' , lreg))
models.append(('Lasso' , ls))
models.append(('ElasticNet' , en))
models.append(('GradientBooster' , gbr))
models.append(('Adaboost' , abr))
models.append(('RandomForestRegressor' , rf))
models.append(('SVR' , svr))

models
# Out:
# [('KNeighborsRegressor',
#   KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                       weights='uniform')),
#  ('LinearRegression',
#   LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                    normalize='False')),
#  ('Lasso',
#   Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#         normalize=False, positive=False, precompute=False, random_state=None,
#         selection='cyclic', tol=0.0001, warm_start=False)),
#  ('ElasticNet',
#   ElasticNet(alpha=100, copy_X=True, fit_intercept=True, l1_ratio=0.4, max_iter=5,
#              normalize=False, positive=False, precompute=False, random_state=None,
#              selection='cyclic', tol=0.0001, warm_start=False)),
#  ('GradientBooster',
#   GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
# ...

# %%
Model = []
r2score = []
cv = []
rmse = []

for name,model in models:
    print("***************************" , name , "***************************\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    r2s = r2_score(y_test,pred)
    print("r2 score :" , r2s)
    r2score.append(r2s*100)
    print("\n")
    sc = cross_val_score(model , x, y , cv = 10 , scoring = 'r2')
    print("Cross_Val_score : " , sc)
    cv.append(sc*100)
    print("\n")
    rme = np.sqrt(mean_squared_error(y_test,pred))
    print("RMSE : " , rme)
    rmse.append(rme)
    print("\n\n")
# Out:
# *************************** KNeighborsRegressor ***************************
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
#
# r2 score : 0.7229693924166288
#
#
# Cross_Val_score :  [ -1.91357558   0.33857143  -0.70142857 -42.59642857   0.40755409
#    0.29870264   0.54977901  -7.469375     0.28348837  -1.81388889]
#
#
# RMSE :  4.104266073246225
#
#
#
# *************************** LinearRegression ***************************
#
# LinearRegression(copy_X='True', fit_intercept='True', n_jobs=None,
#                  normalize='False')
#
#
# r2 score : 0.6086791076001472
#
#
# Cross_Val_score :  [  0.94159505   0.486503   -23.58777131  -6.76551887   0.34345548
#    0.67060973   0.70334731  -1.31230018   0.34550157  -1.59885836]
#
#
# RMSE :  4.877959026362237
#
#
#
# *************************** Lasso ***************************
#
# ...

# %%
result = pd.DataFrame({'Model' : Model , 'R2Score' : r2score , "RMSE" : rmse , "Cross_Val_Score" :cv})

result
# Out:
#                    Model    R2Score      RMSE  \
# 0    KNeighborsRegressor  72.296939  4.104266
# 1       LinearRegression  60.867911  4.877959
# 2                  Lasso  90.598218  2.390984
# 3             ElasticNet  84.839037  3.036233
# 4        GradientBooster  12.601424  7.289938
# 5               Adaboost  88.591508  2.633818
# 6  RandomForestRegressor  78.767691  3.593108
# 7                    SVR  -0.506528  7.817516
#
#                                      Cross_Val_Score
# 0  [-191.3575581395349, 33.85714285714276, -70.14...
# 1  [94.15950479813517, 48.650300334309634, -2358....
# 2  [58.332286170990685, -19.227167601586714, -277...
# 3  [-24.302998906872308, 50.755889694086534, -180...
# 4  [-99.17796501239991, 14.255426297921137, -64.4...
# 5  [69.43015198009559, 67.00056976841609, -996.14...
# 6  [-22.928667151162664, 75.18255306122448, -2961...
# 7  [-122.54839086362841, -11.703148001527076, -34...

# %%
# Best Model we consider is ElasticNet as R2Score is 89.33

max_r2 = 0

for rs in range(30,101):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = rs , test_size = 0.20)
    en = ElasticNet()
    en.fit(x_train,y_train)
    pred=en.predict(x_test)
    r2s = r2_score(y_test,pred)
    if r2s > max_r2:
        max_r2 = r2s
        final_rm = rs
        print("Max R2 Score : " , max_r2 , "Max Random State" , final_rm)
# Out:
# Max R2 Score :  0.8855749256971593 Max Random State 30
# Max R2 Score :  0.9290005497141829 Max Random State 46
# Max R2 Score :  0.9644111590471032 Max Random State 47

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 47 , test_size = 0.20)

en.fit(x_train,y_train)
pred=en.predict(x_test)
R2Score= r2_score(y_test,pred)

print("R2Score : " , R2Score *100)
# Out:
# R2Score :  96.44111590471032

# %%
# Elastic Net model as it has comapratively better r2score

df_pred = en.predict(x_test)

df_predict = pd.DataFrame(df_pred)

df_predict
# Out:
#            0
# 0  98.415976
# 1  71.802810
# 2  76.108899
# 3  86.280096
# 4  74.776502
# 5  63.103215

# %%
from sklearn.externals import joblib

# Save the model as a object file

joblib.dump(en , 'p2_baseball.obj')

#Load the model from the file

dtc_from_joblib = joblib.load('p2_baseball.obj')

# Use the loaded model to make predictions

dtc_from_joblib.predict(x_test)
# Out:
# array([98.4159763 , 71.80280997, 76.10889924, 86.28009558, 74.77650179,
#        63.10321527])

# %%
# Saving Predict to csv

df_predict.to_csv("C:/Users/drash/OneDrive/Desktop/PythonSQL/baseball_predict.csv")
